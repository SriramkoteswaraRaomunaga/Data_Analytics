# %%
pip install pandas sqlalchemy pymysql matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pandas in .\AppData\Roaming\Python\Python314\site-packages (2.3.3)
# Requirement already satisfied: sqlalchemy in .\AppData\Roaming\Python\Python314\site-packages (2.0.49)
# Requirement already satisfied: pymysql in .\AppData\Roaming\Python\Python314\site-packages (1.1.3)
# Requirement already satisfied: matplotlib in .\AppData\Roaming\Python\Python314\site-packages (3.10.8)
# Requirement already satisfied: seaborn in .\AppData\Roaming\Python\Python314\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in .\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Roaming\Python\Python314\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Roaming\Python\Python314\site-packages (from pandas) (2025.3)
# Requirement already satisfied: greenlet>=1 in .\AppData\Roaming\Python\Python314\site-packages (from sqlalchemy) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\AppData\Roaming\Python\Python314\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("cleaned_superstore.csv")

engine = create_engine(
    "mysql+pymysql://root:123@127.0.0.1:3306/data_analytics"
)

df.to_sql(
    name='sales_data',
    con=engine,
    if_exists='replace',
    index=False
)

print("Dataset uploaded successfully!")
# Out:
# Dataset uploaded successfully!
